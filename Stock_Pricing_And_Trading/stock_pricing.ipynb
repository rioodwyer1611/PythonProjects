# %% [markdown]
# # Stock Pricing
#
# ### Reasoning:
# As a broke uni student, I want money. But I also don't want to keep working a low wage, dead end job. Therefore, the best and most obvious method is to make a stock pricer which can list through a variety of options and find the best investment opportunity and give reports, etc, as it applies.

# %% [markdown]
# ## Methodology
#
# 1.

# %%
# Imports:
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import yfinance as yf
import requests

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
